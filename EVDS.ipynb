# %% [markdown]
# <a href="https://colab.research.google.com/github/veyselalevcan/Time_Series/blob/main/EVDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install evds --upgrade

# %%
from evds import evdsAPI
evds = evdsAPI('J2ua6jVeIF')
evds.get_data(['TP.DK.USD.A.YTL','TP.DK.EUR.A.YTL'], startdate="01-01-2019", enddate="01-01-2020")
# Out:
#           Tarih  TP_DK_USD_A_YTL  TP_DK_EUR_A_YTL
# 0    01-01-2019              NaN              NaN
# 1    02-01-2019           5.2810           6.0422
# 2    03-01-2019           5.3316           6.1061
# 3    04-01-2019           5.4588           6.2057
# 4    05-01-2019              NaN              NaN
# ..          ...              ...              ...
# 361  28-12-2019              NaN              NaN
# 362  29-12-2019              NaN              NaN
# 363  30-12-2019           5.9370           6.6117
# 364  31-12-2019           5.9402           6.6506
# 365  01-01-2020              NaN              NaN
#
# [366 rows x 3 columns]

# %%
kat=evds.main_categories
kat
# Out:
#     CATEGORY_ID                                     TOPIC_TITLE_TR
# 0             1                             PİYASA VERİLERİ (TCMB)
# 1             2                                      KURLAR (TCMB)
# 2             3                         FAİZ İSTATİSTİKLERİ (TCMB)
# 3             4          AYLIK PARA VE BANKA İSTATİSTİKLERİ (TCMB)
# 4             5                MENKUL KIYMET İSTATİSTİKLERİ (TCMB)
# 5            12                   FİNANSAL HİZMETLER ANKETİ (TCMB)
# 6            13             MERKEZ BANKASI BİLANÇO VERİLERİ (TCMB)
# 7            14                                   FİYAT ENDEKSLERİ
# 8            15                     İKTİSADİ YÖNELİM ANKETİ (TCMB)
# 9            18              ULUSLARARASI YATIRIM POZİSYONU (TCMB)
# 10           19                  DIŞ TİCARET İSTATİSTİKLERİ (TÜİK)
# 11           20             KAMU MALİYESİ İSTATİSTİKLERİ (HMB,SBB)
# 12           21                      ÜRETİME İLİŞKİN DİĞER VERİLER
# ...

# %%
alt=evds.get_sub_categories(1)
alt
# Out:
#     CATEGORY_ID  DATAGROUP_CODE  \
# 0             1      bie_pyrepo
# 1             1      bie_ppibsm
# 2             1    bie_pyintbnk
# 3             1       bie_tldov
# 4             1      bie_mkbrgn
# 5             1    bie_dovefmud
# 6             1      bie_pydibs
# 7             1    bie_dovefdep
# 8             1     bie_pydovef
# 9             1       bie_rtrnr
# 10            1      bie_apifon
# 11            1      bie_fxswap
# 12            1  bie_onrepofbap
# 13            1   bie_bisttlref
#
#                                        DATAGROUP_NAME
# 0             Açık Piyasa Repo ve Ters Repo İşlemleri
# 1   Bankalar Serbest Mevduatı ve Gün Başı Toplam L...
# 2          Bankalararası Para Piyasası İşlem Özetleri
# 3   Bankaların Türk Lirası Karşılığı Döviz İşlem H...
# 4                  BIST Endeksi ve Günlük İşlem Hacmi
# 5   Dalgalı Döviz Kuru Rejiminde Merkez Bankasınca...
# 6   Devlet İç Borçlanma Senetlerinin Gösterge Nite...
# ...

# %%
seri=evds.get_series('bie_pyintbnk')
seri
# Out:
#         SERIE_CODE                                         SERIE_NAME  \
# 0     TP.PY.P01.1A     (1A) TCMB Kotasyonları ALIŞ (%)(1 Aylık İşlem)
# 1     TP.PY.P01.1H  (1H) TCMB Kotasyonları ALIŞ (%)(1 Haftalık İşlem)
# 2     TP.PY.P01.2A     (2A) TCMB Kotasyonları ALIŞ (%)(2 Aylık İşlem)
# 3     TP.PY.P01.2H  (2H) TCMB Kotasyonları ALIŞ (%)(2 Haftalık İşlem)
# 4     TP.PY.P01.3A     (3A) TCMB Kotasyonları ALIŞ (%)(3 Aylık İşlem)
# ..             ...                                                ...
# 111   TP.PY.P08.KV  (KV) TCMB İşlemleri SATIŞ Tutarı (Bin TL)(Kırı...
# 112  TP.PY.P08.LON  (LON) TCMB İşlemleri SATIŞ Tutarı (Bin TL)(Geç...
# 113   TP.PY.P08.ON  (ON) TCMB İşlemleri SATIŞ Tutarı (Bin TL)(1 Ge...
# 114  TP.PY.P08.T1W  (T1W) TCMB İşlemleri SATIŞ Tutarı (Bin TL)(1 İ...
# 115   TP.PY.P08.TN  (TN) TCMB İşlemleri SATIŞ Tutarı (Bin TL)(1 İş...
#
#      START_DATE
# 0    04-11-1996
# 1    04-11-1996
# 2    04-11-1996
# 3    04-11-1996
# 4    04-11-1996
# ..          ...
# ...

# %%
veri=evds.get_data(['TP.PY.P01.1A'], startdate='01-01-2018', enddate='31-12-2018')
veri
# Out:
#           Tarih  TP_PY_P01_1A
# 0    01-01-2018           NaN
# 1    02-01-2018           NaN
# 2    03-01-2018           NaN
# 3    04-01-2018           NaN
# 4    05-01-2018           NaN
# ..          ...           ...
# 256  25-12-2018           NaN
# 257  26-12-2018           NaN
# 258  27-12-2018           NaN
# 259  28-12-2018           NaN
# 260  31-12-2018           NaN
#
# [261 rows x 2 columns]
